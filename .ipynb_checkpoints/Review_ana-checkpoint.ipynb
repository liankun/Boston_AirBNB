# %%
import pandas as pd
import numpy as np
from numpy import linalg as LA

import nltk
from nltk.tokenize import sent_tokenize,word_tokenize
#refer to https://www.kaggle.com/residentmario/sentiment-analysis-and-collocation-of-reviews
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
from nltk import wordpunct_tokenize
import matplotlib.pyplot as plt

import gensim
from gensim.models.word2vec import LineSentence
from gensim.models import Word2Vec

import codecs

from nltk.stem import WordNetLemmatizer
from nltk.collocations import BigramCollocationFinder
from nltk.metrics import BigramAssocMeasures

import itertools as it
from gensim.models.phrases import Phrases, Phraser
import spacy #https://github.com/skipgram/modern-nlp-in-python/blob/master/executable/Modern_NLP_in_Python.ipynb

# %%
#read data and data cleanning
df_reviews = pd.read_csv('boston/reviews.csv')
df_reviews.head()
# Out:
#    listing_id       id        date  reviewer_id reviewer_name  \
# 0     1178162  4724140  2013-05-21      4298113       Olivier
# 1     1178162  4869189  2013-05-29      6452964     Charlotte
# 2     1178162  5003196  2013-06-06      6449554     Sebastian
# 3     1178162  5150351  2013-06-15      2215611        Marine
# 4     1178162  5171140  2013-06-16      6848427        Andrew
#
#                                             comments
# 0  My stay at islam's place was really cool! Good...
# 1  Great location for both airport and city - gre...
# 2  We really enjoyed our stay at Islams house. Fr...
# 3  The room was nice and clean and so were the co...
# 4  Great location. Just 5 mins walk from the Airp...

# %%
#there are several languages
#we only intereted in English
def get_language_likelihood(input_text):
    """Return a dictionary of languages and their likelihood of being the 
    natural language of the input text
    """
 
    input_text = input_text.lower()
    input_words = wordpunct_tokenize(input_text)
 
    language_likelihood = {}
    total_matches = 0
    for language in stopwords._fileids:
        language_likelihood[language] = len(set(input_words) &
                set(stopwords.words(language)))
 
    return language_likelihood
 
def get_language(input_text):
    """Return the most likely language of the given text
    """ 
    likelihoods = get_language_likelihood(input_text)
    return sorted(likelihoods, key=likelihoods.get, reverse=True)[0]

# %%
#drop na
df_reviews_no_na = df_reviews.dropna().copy()

# %%
#create another columns for language
df_reviews_no_na['language'] = df_reviews_no_na['comments'].apply(get_language)

# %%
#this take a long time to run , we save it
df_reviews_no_na.to_csv('boston/reviews_no_na_add_language_type.csv',index=False)

# %%
df_reviews_lang = pd.read_csv('boston/reviews_no_na_add_language_type.csv')

# %%
#check how many types
df_reviews_lang['language'].value_counts()
# Out:
# english        64001
# french          1285
# arabic          1050
# spanish          630
# german           535
# italian          191
# dutch            184
# portuguese       101
# azerbaijani       99
# danish            58
# russian           27
# swedish           18
# norwegian         16
# greek              8
# romanian           7
# finnish            5
# hungarian          3
# turkish            3
# indonesian         1
# Name: language, dtype: int64

# %%
#most are english, we only intereted in english
df_review_english = df_reviews_lang[df_reviews_lang['language']=='english'].copy()

# %%
#let's clean the data
#we will split each reviews into sentence and then words
#need to run  python -m spacy download en
nlp = spacy.load('C:\\Users\\zzguk\\Anaconda3\\Lib\\site-packages\\en_core_web_sm\\en_core_web_sm-2.0.0')

# %%
#put all txt together

sample_parsed_review = nlp(df_review_english['comments'][0])

# %%
print(sample_parsed_review)
# Out:
# My stay at islam's place was really cool! Good location, 5min away from subway, then 10min from downtown. The room was nice, all place was clean. Islam managed pretty well our arrival, even if it was last minute ;) i do recommand this place to any airbnb user :)

# %%
for num, sentence in enumerate(sample_parsed_review.sents):
    print('Sentence {}:'.format(num+1))
    print(sentence)
    print()
# Out:
# Sentence 1:
# My stay at islam's place was really cool!
#
# Sentence 2:
# Good location, 5min away from subway, then 10min from downtown.
#
# Sentence 3:
# The room was nice, all place was clean.
#
# Sentence 4:
# Islam managed pretty well our arrival, even if it was last minute ;) i do recommand this place to any airbnb user :)

# %%
for num,entity in enumerate(sample_parsed_review.ents):
    print('Entity {}:'.format(num+1),entity,'-',entity.label_)
# Out:
# Entity 1: 5min - CARDINAL
# Entity 2: 10min - CARDINAL
# Entity 3: Islam - ORG
# Entity 4: last minute - TIME

# %%
for token in sample_parsed_review:
    print(token.lemma_)
# Out:
# -PRON-
# stay
# at
# islam
# 's
# place
# be
# really
# cool
# !
# good
# location
# ,
# 5min
# away
# from
# subway
# ,
# then
# 10min
# from
# downtown
# .
# the
# room
# be
# nice
# ,
# all
# place
# be
# clean
# .
# islam
# manage
# pretty
# well
# -PRON-
# arrival
# ,
# even
# if
# -PRON-
# be
# last
# minute
# ;)
# i
# do
# recommand
# this
# place
# to
# any
# airbnb
# user
# :)

# %%
token_text = [token.orth_ for token in sample_parsed_review]
token_pos = [token.pos_ for token in sample_parsed_review]
list(zip(token_text,token_pos))
# Out:
# [('My', 'ADJ'),
#  ('stay', 'NOUN'),
#  ('at', 'ADP'),
#  ('islam', 'NOUN'),
#  ("'s", 'PART'),
#  ('place', 'NOUN'),
#  ('was', 'VERB'),
#  ('really', 'ADV'),
#  ('cool', 'ADJ'),
#  ('!', 'PUNCT'),
#  ('Good', 'ADJ'),
#  ('location', 'NOUN'),
#  (',', 'PUNCT'),
#  ('5min', 'NOUN'),
#  ('away', 'ADV'),
#  ('from', 'ADP'),
#  ('subway', 'NOUN'),
#  (',', 'PUNCT'),
#  ('then', 'ADV'),
#  ('10min', 'VERB'),
#  ('from', 'ADP'),
#  ('downtown', 'NOUN'),
#  ('.', 'PUNCT'),
#  ('The', 'DET'),
#  ('room', 'NOUN'),
#  ('was', 'VERB'),
#  ('nice', 'ADJ'),
#  (',', 'PUNCT'),
#  ('all', 'DET'),
#  ('place', 'NOUN'),
#  ('was', 'VERB'),
#  ('clean', 'ADJ'),
#  ('.', 'PUNCT'),
#  ('Islam', 'PROPN'),
#  ('managed', 'VERB'),
#  ('pretty', 'ADV'),
#  ('well', 'ADV'),
#  ('our', 'ADJ'),
#  ('arrival', 'NOUN'),
#  (',', 'PUNCT'),
#  ('even', 'ADV'),
#  ('if', 'ADP'),
#  ('it', 'PRON'),
#  ('was', 'VERB'),
#  ('last', 'ADJ'),
#  ('minute', 'NOUN'),
#  (';)', 'PUNCT'),
#  ('i', 'PRON'),
#  ('do', 'VERB'),
#  ('recommand', 'ADV'),
#  ('this', 'DET'),
#  ('place', 'NOUN'),
#  ('to', 'ADP'),
#  ('any', 'DET'),
#  ('airbnb', 'ADJ'),
#  ('user', 'NOUN'),
#  (':)', 'PUNCT')]

# %%
token_entity_type = [token.ent_type_ for token in sample_parsed_review]
token_entity_iob = [token.ent_iob_ for token in sample_parsed_review]

# %%
tmp_list = list(zip(token_text, token_entity_type, token_entity_iob))
pd.DataFrame(tmp_list,
             columns=['token_text', 'entity_type', 'inside_outside_begin'])
# Out:
#    token_text entity_type inside_outside_begin
# 0          My                                O
# 1        stay                                O
# 2          at                                O
# 3       islam                                O
# 4          's                                O
# 5       place                                O
# 6         was                                O
# 7      really                                O
# 8        cool                                O
# 9           !                                O
# 10       Good                                O
# 11   location                                O
# 12          ,                                O
# 13       5min    CARDINAL                    B
# 14       away                                O
# 15       from                                O
# 16     subway                                O
# 17          ,                                O
# 18       then                                O
# 19      10min    CARDINAL                    B
# 20       from                                O
# 21   downtown                                O
# 22          .                                O
# 23        The                                O
# 24       room                                O
# 25        was                                O
# 26       nice                                O
# 27          ,                                O
# 28        all                                O
# 29      place                                O
# 30        was                                O
# 31      clean                                O
# 32          .                                O
# 33      Islam         ORG                    B
# 34    managed                                O
# 35     pretty                                O
# 36       well                                O
# 37        our                                O
# 38    arrival                                O
# 39          ,                                O
# 40       even                                O
# 41         if                                O
# 42         it                                O
# 43        was                                O
# 44       last        TIME                    B
# 45     minute        TIME                    I
# 46         ;)                                O
# 47          i                                O
# 48         do                                O
# 49  recommand                                O
# 50       this                                O
# 51      place                                O
# 52         to                                O
# 53        any                                O
# 54     airbnb                                O
# 55       user                                O
# 56         :)                                O

# %%
token_lemma = [token.lemma_ for token in sample_parsed_review]
token_shape = [token.shape_ for token in sample_parsed_review]
pd.DataFrame(list(zip(token_text, token_lemma, token_shape)),
             columns=['token_text', 'token_lemma', 'token_shape'])
# Out:
#    token_text token_lemma token_shape
# 0          My      -PRON-          Xx
# 1        stay        stay        xxxx
# 2          at          at          xx
# 3       islam       islam        xxxx
# 4          's          's          'x
# 5       place       place        xxxx
# 6         was          be         xxx
# 7      really      really        xxxx
# 8        cool        cool        xxxx
# 9           !           !           !
# 10       Good        good        Xxxx
# 11   location    location        xxxx
# 12          ,           ,           ,
# 13       5min        5min        dxxx
# 14       away        away        xxxx
# 15       from        from        xxxx
# 16     subway      subway        xxxx
# 17          ,           ,           ,
# 18       then        then        xxxx
# 19      10min       10min       ddxxx
# 20       from        from        xxxx
# 21   downtown    downtown        xxxx
# 22          .           .           .
# 23        The         the         Xxx
# 24       room        room        xxxx
# 25        was          be         xxx
# 26       nice        nice        xxxx
# 27          ,           ,           ,
# 28        all         all         xxx
# 29      place       place        xxxx
# 30        was          be         xxx
# 31      clean       clean        xxxx
# 32          .           .           .
# 33      Islam       islam       Xxxxx
# 34    managed      manage        xxxx
# 35     pretty      pretty        xxxx
# 36       well        well        xxxx
# 37        our      -PRON-         xxx
# 38    arrival     arrival        xxxx
# 39          ,           ,           ,
# 40       even        even        xxxx
# 41         if          if          xx
# 42         it      -PRON-          xx
# 43        was          be         xxx
# 44       last        last        xxxx
# 45     minute      minute        xxxx
# 46         ;)          ;)          ;)
# 47          i           i           x
# 48         do          do          xx
# 49  recommand   recommand        xxxx
# 50       this        this        xxxx
# 51      place       place        xxxx
# 52         to          to          xx
# 53        any         any         xxx
# 54     airbnb      airbnb        xxxx
# 55       user        user        xxxx
# 56         :)          :)          :)

# %%
token_entity_type = [token.ent_type_ for token in sample_parsed_review]
token_entity_iob = [token.ent_iob_ for token in sample_parsed_review]

pd.DataFrame(list(zip(token_text, token_entity_type, token_entity_iob)),
             columns=['token_text', 'entity_type', 'inside_outside_begin'])
# Out:
#    token_text entity_type inside_outside_begin
# 0          My                                O
# 1        stay                                O
# 2          at                                O
# 3       islam                                O
# 4          's                                O
# 5       place                                O
# 6         was                                O
# 7      really                                O
# 8        cool                                O
# 9           !                                O
# 10       Good                                O
# 11   location                                O
# 12          ,                                O
# 13       5min    CARDINAL                    B
# 14       away                                O
# 15       from                                O
# 16     subway                                O
# 17          ,                                O
# 18       then                                O
# 19      10min    CARDINAL                    B
# 20       from                                O
# 21   downtown                                O
# 22          .                                O
# 23        The                                O
# 24       room                                O
# 25        was                                O
# 26       nice                                O
# 27          ,                                O
# 28        all                                O
# 29      place                                O
# 30        was                                O
# 31      clean                                O
# 32          .                                O
# 33      Islam         ORG                    B
# 34    managed                                O
# 35     pretty                                O
# 36       well                                O
# 37        our                                O
# 38    arrival                                O
# 39          ,                                O
# 40       even                                O
# 41         if                                O
# 42         it                                O
# 43        was                                O
# 44       last        TIME                    B
# 45     minute        TIME                    I
# 46         ;)                                O
# 47          i                                O
# 48         do                                O
# 49  recommand                                O
# 50       this                                O
# 51      place                                O
# 52         to                                O
# 53        any                                O
# 54     airbnb                                O
# 55       user                                O
# 56         :)                                O

# %%
token_attributes = [(token.orth_,
                     token.prob,
                     token.is_stop,
                     token.is_punct,
                     token.is_space,
                     token.like_num,
                     token.is_oov)
                    for token in sample_parsed_review]

df = pd.DataFrame(token_attributes,
                  columns=['text',
                           'log_probability',
                           'stop?',
                           'punctuation?',
                           'whitespace?',
                           'number?',
                           'out of vocab.?'])

df.loc[:, 'stop?':'out of vocab.?'] = (df.loc[:, 'stop?':'out of vocab.?']
                                       .applymap(lambda x: u'Yes' if x else u''))
                                               
df
# Out:
#          text  log_probability stop? punctuation? whitespace? number?  \
# 0          My            -20.0
# 1        stay            -20.0
# 2          at            -20.0   Yes
# 3       islam            -20.0
# 4          's            -20.0
# 5       place            -20.0
# 6         was            -20.0   Yes
# 7      really            -20.0   Yes
# 8        cool            -20.0
# 9           !            -20.0                Yes
# 10       Good            -20.0
# 11   location            -20.0
# 12          ,            -20.0                Yes
# 13       5min            -20.0
# 14       away            -20.0
# 15       from            -20.0   Yes
# 16     subway            -20.0
# 17          ,            -20.0                Yes
# 18       then            -20.0   Yes
# 19      10min            -20.0
# 20       from            -20.0   Yes
# 21   downtown            -20.0
# 22          .            -20.0                Yes
# 23        The            -20.0
# 24       room            -20.0
# 25        was            -20.0   Yes
# 26       nice            -20.0
# 27          ,            -20.0                Yes
# 28        all            -20.0   Yes
# 29      place            -20.0
# 30        was            -20.0   Yes
# 31      clean            -20.0
# 32          .            -20.0                Yes
# 33      Islam            -20.0
# 34    managed            -20.0
# 35     pretty            -20.0
# 36       well            -20.0   Yes
# 37        our            -20.0   Yes
# 38    arrival            -20.0
# 39          ,            -20.0                Yes
# 40       even            -20.0   Yes
# 41         if            -20.0   Yes
# 42         it            -20.0   Yes
# 43        was            -20.0   Yes
# 44       last            -20.0   Yes
# 45     minute            -20.0
# 46         ;)            -20.0                Yes
# 47          i            -20.0   Yes
# 48         do            -20.0   Yes
# 49  recommand            -20.0
# 50       this            -20.0   Yes
# 51      place            -20.0
# 52         to            -20.0   Yes
# 53        any            -20.0   Yes
# 54     airbnb            -20.0
# 55       user            -20.0
# 56         :)            -20.0                Yes
#
#    out of vocab.?
# 0             Yes
# 1             Yes
# 2             Yes
# 3             Yes
# 4             Yes
# 5             Yes
# 6             Yes
# 7             Yes
# 8             Yes
# 9             Yes
# 10            Yes
# 11            Yes
# 12            Yes
# 13            Yes
# 14            Yes
# 15            Yes
# 16            Yes
# 17            Yes
# 18            Yes
# 19            Yes
# 20            Yes
# 21            Yes
# 22            Yes
# 23            Yes
# 24            Yes
# 25            Yes
# 26            Yes
# 27            Yes
# 28            Yes
# 29            Yes
# 30            Yes
# 31            Yes
# 32            Yes
# 33            Yes
# 34            Yes
# 35            Yes
# 36            Yes
# 37            Yes
# 38            Yes
# 39            Yes
# 40            Yes
# 41            Yes
# 42            Yes
# 43            Yes
# 44            Yes
# 45            Yes
# 46            Yes
# 47            Yes
# 48            Yes
# 49            Yes
# 50            Yes
# 51            Yes
# 52            Yes
# 53            Yes
# 54            Yes
# 55            Yes
# 56            Yes

# %%
def punct_space(token):
    """
    helper function to eliminate tokens
    that are pure punctuation or whitespace
    """
    
    return token.is_punct or token.is_space

# %%
def punct_space_stop(token):
    """
    helper function to eliminate tokens
    that are pure punctuation or whitespace
    """
    
    return token.is_punct or token.is_space or token.is_stop

# %%
def lemmatized_sentence_corpus():
    for rev in df_review_english['comments']:
        parsed_rev = nlp(rev)
        for sent in parsed_rev.sents:
            yield u' '.join([token.lemma_ for token in sent 
                             if not punct_space_stop(token)])

# %%
#let's put all sentence into a file 
#it take some times
if True:
    with codecs.open('review_sentences_in_all_no_stop.txt','w',encoding='utf_8') as f:
        for sentence in lemmatized_sentence_corpus():
            f.write(sentence+'\n')

# %%
reveiw_sentences = LineSentence('review_sentences_in_all.txt')

# %%
ct=0
for sent in reveiw_sentences:
    print(sent)
    ct += 1
    if ct>5:
        break
# Out:
# ['-PRON-', 'stay', 'at', 'islam', "'s", 'place', 'be', 'really', 'cool']
# ['good', 'location', '5min', 'away', 'from', 'subway', 'then', '10min', 'from', 'downtown']
# ['the', 'room', 'be', 'nice', 'all', 'place', 'be', 'clean']
# ['islam', 'manage', 'pretty', 'well', '-PRON-', 'arrival', 'even', 'if', '-PRON-', 'be', 'last', 'minute', 'i', 'do', 'recommand', 'this', 'place', 'to', 'any', 'airbnb', 'user']
# ['great', 'location', 'for', 'both', 'airport', 'and', 'city', 'great', 'amenity', 'in', 'the', 'house', 'plus']
# ['islam', 'be', 'always', 'very', 'helpful', 'even', 'though', '-PRON-', 'be', 'away']

# %%
#write to a txt file
if False:
    bigram_model = Phrases(reveiw_sentences)
    bigram_model.save('bigram_review_all')
bigram_model = Phrases.load('bigram_review_all')

# %%
if False:
    with codecs.open('bigram_review_sentences_all.txt','w',encoding='utf_8') as f:
        for sentence in reveiw_sentences:
            bigram_sent = u' '.join(bigram_model[sentence])
            f.write(bigram_sent + '\n')

# %%
rev_bigram_sentences = LineSentence('bigram_review_sentences_all.txt')

# %%
#let's do it again to get trigram and save the model
if False:
    trigram_model = Phrases(rev_bigram_sentences)
    trigram_model.save('trigram_review_all')
trigram_model = Phrases.load('trigram_review_all')

# %%
#let's save the trigram sentences
if False:
    with codecs.open('trigram_review_sentences_all.txt','w',encoding='utf_8') as f:
        for sentence in rev_bigram_sentences:
            trigram_sent = u' '.join(trigram_model[sentence])
            f.write(trigram_sent + '\n')

# %%
rev_trigram_sentences = LineSentence('trigram_review_sentences_all.txt')

# %%
#let's create a file with one review per line
if False:
    with codecs.open('trigram_review_one_review_per_line.txt','w',encoding='utf_8') as f:
        for rev in df_review_english['comments']:
            parsed_rev = nlp(rev)
            unigram_rev = [token.lemma_ for token in parsed_rev if not punct_space(token)]
            #apply the first-order and second-order phrase model
            bigram_rev = bigram_model[unigram_rev]
            trigram_rev = trigram_model[bigram_rev]
            #remove stop words
            trigram_rev = [term for term in trigram_rev 
                           if term not in spacy.lang.en.stop_words.STOP_WORDS]
            
            #write to a new file
            trigram_rev = u' '.join(trigram_rev)
            f.write(trigram_rev+'\n')

# %%
from gensim.corpora import Dictionary, MmCorpus
from gensim.models.ldamulticore import LdaMulticore

import pyLDAvis
import pyLDAvis.gensim
import warnings

# %%
# %%time
if False:
    trigram_rev = LineSentence('trigram_review_one_review_per_line.txt')
    trigram_dic = Dictionary(trigram_rev)
    trigram_dic.filter_extremes(no_below=10,no_above=0.4)
    trigram_dic.compactify()
    trigram_dic.save('traigram_review_dict.dict')
trigram_dic = Dictionary.load('traigram_review_dict.dict')
# Out:
# Wall time: 4.99 ms

# %%
def trigram_bow_generator(filepath):
    """
    generator function to read reviews from a file
    and yield a bag-of-words representation
    """
    
    for review in LineSentence(filepath):
        yield trigram_dic.doc2bow(review)

# %%
if False:
    MmCorpus.serialize('trigram_review_bow_corpus_all.mm',
                      trigram_bow_generator('trigram_review_one_review_per_line.txt'))
trigram_bow_corpus = MmCorpus('trigram_review_bow_corpus_all.mm')

# %%
if True:
    with warnings.catch_warnings():
        warnings.simplefilter('ignore')
        
        lda = LdaMulticore(trigram_bow_corpus,
                          num_topics=50,
                          id2word=trigram_dic,
                          workers=3)
        lda.save('lda_review_model_all')
lda = LdaMulticore.load('lda_review_model_all')

# %%
def explore_topic(topic_number, topn=25):
    """
    accept a user-supplied topic number and
    print out a formatted list of the top terms
    """
        
    print( u'{:20} {}'.format(u'term', u'frequency') + u'\n')

    for term, frequency in lda.show_topic(topic_number, topn=25):
        print(u'{:20} {:.3f}'.format(term, round(frequency, 3)))

# %%
explore_topic(topic_number=0)
# Out:
# term                 frequency
#
# good                 0.030
# room                 0.024
# nice                 0.022
# place                0.015
# bed                  0.015
# need                 0.013
# clean                0.012
# house                0.010
# flat                 0.010
# apartment            0.010
# boston               0.010
# comfortable          0.010
# time                 0.010
# host                 0.010
# use                  0.009
# location             0.008
# kitchen              0.008
# bathroom             0.008
# steve                0.007
# night                0.007
# lot                  0.007
# perfect              0.006
# helpful              0.005
# bit                  0.005
# 's                   0.005

# %%
#word2vector
if False:
    review_sentence2vec = Word2Vec(rev_trigram_sentences,size=100,window=5,
                                  min_count=20,sg=1,workers=4)
    review_sentence2vec.save('review_trigram_sentence_w2v_model')
    
    #perform another 11 epochs of training
    for i in range(1,12):
        review_sentence2vec.train(rev_trigram_sentences,
                                  total_examples=review_sentence2vec.corpus_count,
                                  epochs=review_sentence2vec.iter)
        review_sentence2vec.save('review_trigram_sentence_w2v_model')

review_sentence2vec = Word2Vec.load('review_trigram_sentence_w2v_model')
review_sentence2vec.init_sims()

print(u'{} training epochs so far.'.format(review_sentence2vec.train_count))
# Out:
# C:\Users\zzguk\Anaconda3\lib\site-packages\gensim\utils.py:491: DeprecationWarning: Call to deprecated `cum_table` (Attribute will be removed in 4.0.0, use self.vocabulary.cum_table instead).
#   setattr(self, attrib, None)
# 12 training epochs so far.

# %%
print(u'{:,} terms in the food2vec vocabulary.'.format(len(review_sentence2vec.wv.vocab)))
# Out:
# 5,104 terms in the food2vec vocabulary.

# %%
review_sentence2vec.wv.most_similar(positive=['airport'],topn=10)
# Out:
# [('logan_airport', 0.8081258535385132),
#  ('logan', 0.7609093189239502),
#  ('airport_shuttle', 0.7175217866897583),
#  ('blue_line', 0.7128446102142334),
#  ('south_station', 0.6744409799575806),
#  ('train_station', 0.6678196787834167),
#  ('train', 0.6494198441505432),
#  ('bus_station', 0.6468003392219543),
#  ('subway_station', 0.6281470060348511),
#  ('red_line', 0.6235874891281128)]

# %%
review_sentence2vec.wv.most_similar(positive=['bed'],topn=10)
# Out:
# [('mattress', 0.7756842374801636),
#  ('queen_bed', 0.7544865608215332),
#  ('sofa_bed', 0.7341449856758118),
#  ('sofa', 0.7092766761779785),
#  ('couch', 0.7027804255485535),
#  ('king_size_bed', 0.6978681087493896),
#  ('futon', 0.6920413374900818),
#  ('double_bed', 0.6893474459648132),
#  ('queen_size_bed', 0.6831704378128052),
#  ('soft', 0.6745144128799438)]

# %%
review_sentence2vec.wv.most_similar(positive=['tv'],topn=10)
# Out:
# [('cable', 0.8065526485443115),
#  ('television', 0.7724809646606445),
#  ('netflix', 0.7711915373802185),
#  ('internet', 0.7470119595527649),
#  ('wifi', 0.7450128793716431),
#  ('cable_tv', 0.7437824010848999),
#  ('big_screen_tv', 0.71254563331604),
#  ('wi_fi', 0.6935455799102783),
#  ('desk', 0.6721540689468384),
#  ('roku', 0.6653614640235901)]

# %%
review_sentence2vec.wv.most_similar(positive=['neighbor'],topn=10)
# Out:
# [('neighbour', 0.7146357297897339),
#  ('hear', 0.631752610206604),
#  ('upstairs_neighbor', 0.5861818790435791),
#  ('other_resident', 0.5729456543922424),
#  ('loud', 0.5520524382591248),
#  ('loud_music', 0.5497045516967773),
#  ('noise', 0.5460641384124756),
#  ('can_hear', 0.5417159795761108),
#  ('other_tenant', 0.517612874507904),
#  ('sound', 0.5099065899848938)]

# %%
review_sentence2vec.wv.most_similar(positive=['host'],topn=10)
# Out:
# [('hostess', 0.8229786157608032),
#  ('communicator', 0.6656448841094971),
#  ('hospitable', 0.644488513469696),
#  ('host-', 0.6127679347991943),
#  ('gracious', 0.6104849576950073),
#  ('personable', 0.6006618738174438),
#  ('attentive', 0.5932565927505493),
#  ('considerate', 0.5810315608978271),
#  ('friendly', 0.5787869095802307),
#  ('guy', 0.5767316222190857)]

# %%
review_sentence2vec.wv.most_similar(positive=['boston'],topn=10)
# Out:
# [('city', 0.639961838722229),
#  ('town', 0.6019673347473145),
#  ('jp', 0.5748947858810425),
#  ('charlestown', 0.5706949234008789),
#  ('back_bay', 0.5489070415496826),
#  ('beacon_hill', 0.5375350117683411),
#  ('cambridge', 0.5266633033752441),
#  ('jamaica_plain', 0.5227924585342407),
#  ('brighton', 0.4875602722167969),
#  ('southie', 0.48463156819343567)]

# %%
review_sentence2vec.wv.most_similar(positive=['jp'],topn=10)
# Out:
# [('jamaica_plain', 0.8794835805892944),
#  ('jamaica_plains', 0.7328989505767822),
#  ('brighton', 0.6602212190628052),
#  ('allston', 0.6491808891296387),
#  ('charlestown', 0.6479492783546448),
#  ('south_end', 0.6315352320671082),
#  ('boston', 0.574894905090332),
#  ('southie', 0.570213794708252),
#  ('roslindale', 0.5650550127029419),
#  ('brookline', 0.560840904712677)]

# %%
review_sentence2vec.wv.most_similar(positive=['bad'],topn=10)
# Out:
# [('unpleasant', 0.6209224462509155),
#  ('negative', 0.589124858379364),
#  ('terrible', 0.5879950523376465),
#  ('affect', 0.5335972309112549),
#  ('disappointed', 0.5305222272872925),
#  ('shabby', 0.5259073376655579),
#  ('horrible', 0.525062084197998),
#  ('dangerous', 0.5227634906768799),
#  ('awful', 0.5064366459846497),
#  ('uncomfortable', 0.5013737678527832)]

# %%
review_sentence2vec.wv.most_similar(positive=['excellent'],topn=10)
# Out:
# [('superb', 0.7271011471748352),
#  ('great', 0.7252517342567444),
#  ('fantastic', 0.7035104036331177),
#  ('terrific', 0.6866995096206665),
#  ('outstanding', 0.6653568744659424),
#  ('amazing', 0.6278690099716187),
#  ('an_excellent', 0.6229701042175293),
#  ('exceptional', 0.6162222623825073),
#  ('good', 0.6133238673210144),
#  ('top_notch', 0.6099241971969604)]

# %%
review_sentence2vec.wv.most_similar(positive=['close'],topn=10)
# Out:
# [('near', 0.787339448928833),
#  ('walk_distance', 0.6966915726661682),
#  ('within_walking_distance', 0.6699106097221375),
#  ('close_proximity', 0.6687144041061401),
#  ('walkable', 0.6620372533798218),
#  ('within_walk_distance', 0.6316289901733398),
#  ('closeby', 0.6203694343566895),
#  ('proximity', 0.6195684671401978),
#  ('short_walk', 0.6099092960357666),
#  ('convenient', 0.6084648370742798)]

# %%
# Out:
# ['-PRON-',
#  'be',
#  'the',
#  'and',
#  'to',
#  'a',
#  'in',
#  'very',
#  'of',
#  'for',
#  'stay',
#  'have',
#  'great',
#  'with',
#  'place',
#  'boston',
#  'apartment',
#  'not',
#  'clean',
#  'location',
#  'this',
#  'at',
#  'host',
#  'room',
#  'there',
#  'but',
#  'nice',
#  'that',
#  'on',
#  'as',
#  'good',
#  "'s",
#  'from',
#  'comfortable',
#  'do',
#  'so',
#  'would',
#  'all',
#  'house',
#  'get',
#  'everything',
#  'need',
#  'easy',
#  'really',
#  'make',
#  'time',
#  'if',
#  'home',
#  'perfect',
#  'neighborhood',
#  'also',
#  'close',
#  'feel',
#  'which',
#  'just',
#  'again',
#  'when',
#  'helpful',
#  'an',
#  'thank',
#  'area',
#  'recommend',
#  'experience',
#  'bed',
#  'will',
#  'restaurant',
#  'night',
#  'could',
#  'like',
#  'one',
#  'welcome',
#  'walk',
#  'out',
#  'go',
#  'friendly',
#  'about',
#  'wonderful',
#  'quiet',
#  'well',
#  'only',
#  'enjoy',
#  'beautiful',
#  'or',
#  'can',
#  'even',
#  'around',
#  'convenient',
#  'day',
#  'love',
#  'bathroom',
#  'visit',
#  'by',
#  'lot',
#  'check',
#  'provide',
#  'lovely',
#  'would_definitely',
#  'give',
#  'some',
#  'use',
#  'city',
#  'kitchen',
#  'find',
#  'space',
#  'highly_recommend',
#  'accommodate',
#  'meet',
#  'downtown',
#  'much',
#  'leave',
#  'super',
#  'here',
#  'arrive',
#  'work',
#  'two',
#  'right',
#  'take',
#  'spacious',
#  'during',
#  'airbnb',
#  'up',
#  'what',
#  'more',
#  'street',
#  'first',
#  'help',
#  'thing',
#  'little',
#  'trip',
#  'want',
#  'cozy',
#  'safe',
#  'access',
#  'look',
#  'small',
#  'here_again',
#  'see',
#  'other',
#  'fantastic',
#  'definitely',
#  'come',
#  'overall',
#  'bedroom',
#  'responsive',
#  'away',
#  'people',
#  'family',
#  't',
#  'breakfast',
#  'extremely',
#  'airport',
#  'arrival',
#  'into',
#  'no',
#  'after',
#  'picture',
#  'able',
#  'many',
#  'where',
#  'way',
#  'parking',
#  'friend',
#  'quick',
#  'subway',
#  'kind',
#  'amazing',
#  'while',
#  'near',
#  'too',
#  'back',
#  'communication',
#  'excellent',
#  'book',
#  'before',
#  'locate',
#  'warm',
#  'building',
#  'because',
#  'quite',
#  'sleep',
#  'question',
#  'most',
#  'studio',
#  '2',
#  'awesome',
#  'key',
#  'who',
#  'available',
#  'how',
#  'any',
#  'guest',
#  'make_sure',
#  'travel',
#  'next',
#  'both',
#  'town',
#  'always',
#  'know',
#  'plenty',
#  'nearby',
#  'few',
#  'late',
#  'shop',
#  'absolutely',
#  'show',
#  'etc',
#  'spend',
#  'couple',
#  'big',
#  'coffee',
#  'morning',
#  'food',
#  'such',
#  'offer',
#  'say',
#  'person',
#  'than',
#  'short',
#  'eat',
#  'large',
#  'park',
#  'pleasant',
#  'share',
#  'come_back',
#  'may',
#  'ask',
#  'listing',
#  'hotel',
#  'live',
#  'check_out',
#  'expect',
#  'towel',
#  'spot',
#  'respond',
#  'neighbourhood',
#  'car',
#  'unit',
#  '3',
#  'jason',
#  'view',
#  'let',
#  'although',
#  'amenity',
#  'explore',
#  'bit',
#  'over',
#  'enough',
#  'think',
#  'part',
#  'since',
#  'local',
#  'keep',
#  'train',
#  'north_end',
#  'welcoming',
#  'early',
#  'shower',
#  'bus',
#  'pretty',
#  'return',
#  'door',
#  'down',
#  'communicate',
#  'bar',
#  'include',
#  'price',
#  'weekend',
#  'sean',
#  'within',
#  'ever',
#  'accommodation',
#  'as_describe',
#  'week',
#  'private',
#  'appreciate',
#  'old',
#  'short_walk',
#  'every',
#  'however',
#  'anyone',
#  'full',
#  'happy',
#  'public_transportation',
#  'especially',
#  'apt',
#  'problem',
#  'cute',
#  'walk_distance',
#  'lisa',
#  'own',
#  'next_time',
#  'flexible',
#  'never',
#  'flat',
#  'fine',
#  'anything',
#  'instruction',
#  'charming',
#  'information',
#  'issue',
#  'though',
#  'contact',
#  'plan',
#  'off',
#  'recommendation',
#  'answer',
#  'accurate',
#  'through',
#  'cool',
#  'an_excellent',
#  'condo',
#  'then',
#  'flight',
#  'new',
#  'easily',
#  'rent',
#  'corner',
#  'husband',
#  'stop',
#  'comfy',
#  'long',
#  'try',
#  'exactly_as_describe',
#  'common',
#  'description',
#  'direction',
#  '4',
#  'seem',
#  'another',
#  'wifi',
#  'far',
#  'within_walking_distance',
#  't_station',
#  'reservation',
#  'central',
#  'an_amazing',
#  'living_room',
#  'block',
#  'photo',
#  'future',
#  'wait',
#  'open',
#  'hope',
#  'window',
#  'several',
#  'quickly',
#  'evening',
#  'sarah',
#  'touch',
#  'outside',
#  'property',
#  'luggage',
#  'three',
#  'allow',
#  'dog',
#  'fun',
#  'drive',
#  'back_bay',
#  'robert',
#  'gracious',
#  'still',
#  'heart',
#  'whole',
#  'sure',
#  'susan',
#  'i',
#  'tv',
#  'email',
#  'call',
#  'should',
#  'tell',
#  'incredibly',
#  'tip',
#  'light',
#  'clear',
#  'well_equip',
#  'hour',
#  'store',
#  'fridge',
#  'water',
#  'cat',
#  'station',
#  'ideal',
#  'tidy',
#  'even_though',
#  'noise',
#  'floor',
#  'simple',
#  'bring',
#  'suggestion',
#  'without',
#  'talk',
#  'hermina',
#  'beacon_hill',
#  'run',
#  'greet',
#  'an_automate_posting',
#  'privacy',
#  'train_station',
#  'subway_station',
#  'hot',
#  'free',
#  'modern',
#  'tom',
#  'wish',
#  'neat',
#  'same',
#  'stair',
#  'plus',
#  'value',
#  'any_question',
#  'cook',
#  'ready',
#  'freedom_trail',
#  'reach',
#  'throughout',
#  'detail',
#  'well_locate',
#  '5',
#  'second',
#  'sweet',
#  'no_problem',
#  'once',
#  'walking_distance',
#  'jamaica_plain',
#  'more_than',
#  'end',
#  '1',
#  'start',
#  'definitely_recommend',
#  'across',
#  'snack',
#  'hospitality',
#  'extra',
#  'request',
#  'cafe',
#  'actually',
#  'shopping',
#  'message',
#  'orange_line',
#  'guy',
#  't.',
#  'note',
#  'red_line',
#  'chance',
#  'due',
#  'rest',
#  'wife',
#  'advice',
#  'conveniently_locate',
#  'certainly',
#  'perfectly',
#  'metro',
#  'fenway',
#  'dinner',
#  'list',
#  'conference',
#  'interesting',
#  'center',
#  'first_airbnb_experience',
#  'tour',
#  'sheet',
#  'front',
#  'move',
#  'text',
#  'joe',
#  'bag',
#  'process',
#  'attentive',
#  'truly',
#  'consider',
#  'describe',
#  'entire',
#  'daughter',
#  't_stop',
#  'host_cancel_this',
#  'son',
#  'option',
#  'south_end',
#  'appartment',
#  'mention',
#  'accessible',
#  'hospitable',
#  'fast',
#  'until',
#  'map',
#  'chris',
#  'put',
#  'deal',
#  'prepare',
#  'something',
#  'size',
#  'choose',
#  'different',
#  'transportation',
#  'owner',
#  'ride',
#  'service',
#  'basement',
#  'send',
#  'jp',
#  'go_back',
#  'everyone',
#  'bright',
#  'minute',
#  'enjoyable',
#  'prompt',
#  'huge',
#  'drink',
#  'schedule',
#  'uber',
#  'ok',
#  'beyond',
#  'immediately',
#  'cosy',
#  'street_parking',
#  'top',
#  'jose',
#  'exactly_as',
#  'prior',
#  'delicious',
#  'inside',
#  'hear',
#  'point',
#  'gorgeous',
#  'communicative',
#  'invite',
#  'basic',
#  'totally',
#  'four',
#  'public_transport',
#  'fabulous',
#  'along',
#  'grocery_store',
#  'set',
#  'ari',
#  'jonathan',
#  'chat',
#  'anywhere',
#  'exactly_what',
#  'pleasure',
#  'unfortunately',
#  'choice',
#  'bad',
#  'smooth',
#  'wine',
#  'soon',
#  'middle',
#  'day_before_arrival',
#  'lock',
#  'group',
#  'almost',
#  'everywhere',
#  'hard',
#  'change',
#  'just_as_describe',
#  'step',
#  'block_away',
#  'pay',
#  'possible',
#  'kid',
#  'real',
#  'thoughtful',
#  'bruce',
#  'busy',
#  'cold',
#  'relax',
#  'those',
#  'supply',
#  'site',
#  'probably',
#  'generous',
#  'historic',
#  'facility',
#  'yet',
#  'as_advertise',
#  'bus_stop',
#  'each',
#  'fit',
#  'toiletry',
#  'nothing',
#  'side',
#  'steve',
#  'terrific',
#  '5_minute_walk',
#  'ac',
#  'someone',
#  'last',
#  'ton',
#  'dan',
#  'well_appoint',
#  'fan',
#  'reply',
#  'take_care',
#  'hostess',
#  'izzy',
#  'beat',
#  'alex',
#  'linen',
#  'stock',
#  'conversation',
#  'fact',
#  'spotless',
#  'case',
#  'boyfriend',
#  'tea',
#  'worth',
#  'couch',
#  'neighbor',
#  'whole_foods',
#  'other_guest',
#  'literally',
#  'fenway_park',
#  'between',
#  'john',
#  'upstairs',
#  'mind',
#  'expectation',
#  'miss',
#  'main',
#  'barney',
#  'receive',
#  'well_keep',
#  'laundry',
#  'rental',
#  'meal',
#  '10_minute_walk',
#  'attraction',
#  'cambridge',
#  'wall',
#  'mary',
#  'set_up',
#  'parent',
#  'sit',
#  'peaceful',
#  'supermarket',
#  '6',
#  'suggest',
#  'dirty',
#  'green_line',
#  'last_minute',
#  'stuff',
#  'garden',
#  'noisy',
#  'loft',
#  'internet',
#  'michelle',
#  'convention_center',
#  'information_about',
#  'despite',
#  'difficult',
#  'dining',
#  'smell',
#  'jay',
#  'metro_station',
#  'jeff',
#  'fix',
#  'already',
#  'sara',
#  'south',
#  'review',
#  'later',
#  'adorable',
#  'treat',
#  'coffee_shop',
#  'table',
#  'above',
#  'booking',
#  'via',
#  'pick',
#  'ed',
#  'add',
#  'bottle',
#  'attend',
#  'look_forward',
#  'cindy',
#  'bernie',
#  'concern',
#  'breeze',
#  'head',
#  'either',
#  'departure',
#  'pass',
#  'mike',
#  'info',
#  'care',
#  'bath',
#  'these',
#  'professional',
#  'downstairs',
#  'money',
#  'furniture',
#  'upon',
#  'business',
#  'completely',
#  'mattress',
#  'upon_arrival',
#  'grocery',
#  'less_than',
#  'month',
#  'well_stock',
#  'anyone_look',
#  'line',
#  'loud',
#  'sight',
#  'comfort',
#  '10_minute',
#  'base',
#  'end_up',
#  'weather',
#  'centrally_locate',
#  'high',
#  'brian',
#  'roommate',
#  'quaint',
#  'mean',
#  'girlfriend',
#  'considerate',
#  'ensure',
#  'andrea',
#  'vacation',
#  'closet',
#  'within_walk_distance',
#  'fresh',
#  'job',
#  'character',
#  'convenience',
#  'watch',
#  'anthony',
#  'regard',
#  'air_conditioning',
#  'immaculate',
#  'charlestown',
#  'bother',
#  'catch',
#  'summer',
#  'condition',
#  'otherwise',
#  'muffin',
#  'pleased',
#  'arrange',
#  'market',
#  'always_available',
#  'number',
#  'tiffany',
#  '$',
#  'paul',
#  '’s',
#  'organized',
#  'cheap',
#  'moment',
#  'james',
#  'andrew',
#  'commons',
#  'glad',
#  'enter',
#  'adam',
#  'whenever',
#  'easily_accessible',
#  'city_center',
#  'terry',
#  'explain',
#  'public_transit',
#  'sightseeing',
#  'elizabeth',
#  'phone',
#  'ravi',
#  'traveler',
#  'maybe',
#  'fairly',
#  'walkable',
#  'handy',
#  'guide',
#  'now',
#  'life',
#  'longer',
#  'well_maintain',
#  'delay',
#  'useful',
#  'deck',
#  'julie',
#  'response',
#  'charm',
#  'comfy_bed',
#  'essential',
#  'true',
#  'company',
#  'hop',
#  'state',
#  'incredible',
#  'drop',
#  'delightful',
#  'promptly',
#  'decorate',
#  'secure',
#  'pillow',
#  'phyllis',
#  'c',
#  'marathon',
#  'cancel',
#  'follow',
#  'special',
#  'bill',
#  'traffic',
#  'desk',
#  'david',
#  'affordable',
#  'beach',
#  'frank',
#  'willing',
#  'important',
#  'other_than',
#  'half',
#  'pick_up',
#  'manage',
#  'history',
#  'buy',
#  'answer_any_question',
#  'road',
#  '15_minute',
#  'foot',
#  'forget',
#  'item',
#  'relaxing',
#  '20_minute',
#  'situate',
#  'minute_walk',
#  'alan',
#  'order',
#  'simply',
#  'liz',
#  'centre',
#  'heat',
#  '10',
#  'cooking',
#  'jessica',
#  'appear',
#  'unique',
#  'homey',
#  'front_door',
#  'long_day',
#  'superb',
#  'fill',
#  'nicely',
#  'visitor',
#  'private_bathroom',
#  'go_above',
#  'proximity',
#  'cleanliness',
#  'personally',
#  'fruit',
#  'aware',
#  'hang_out',
#  'college',
#  'entrance',
#  'opportunity',
#  'break',
#  'play',
#  'distance',
#  'turn',
#  'arrangement',
#  'happen',
#  'transit',
#  'museum',
#  'hand',
#  'tourist',
#  'favorite',
#  'never_meet',
#  'trouble',
#  'settle',
#  'victoria',
#  'bonus',
#  'read',
#  'addition',
#  'party',
#  'south_station',
#  'matt',
#  'would_not_hesitate',
#  'save',
#  'respond_quickly',
#  'harvard',
#  'danielle',
#  'connect',
#  '5_minute',
#  'michael',
#  '7',
#  'sally',
#  'few_minute',
#  'decor',
#  'jim',
#  'robin',
#  'uncomfortable',
#  't_line',
#  'complete',
#  'walk_everywhere',
#  'exactly_as_picture',
#  'under',
#  'confortable',
#  'little_bit',
#  'green',
#  'seamless',
#  'arrive_late',
#  'expensive',
#  'course',
#  'brownstone',
#  'margaret',
#  'quality',
#  'pretty_much',
#  'system',
#  'no_issue',
#  'cost',
#  'taxi',
#  'decide',
#  'situation',
#  'edward',
#  'dryer',
#  'navigate',
#  'carry',
#  'activity',
#  'together',
#  'personal',
#  'appliance',
#  'newbury_street',
#  'cynthia',
#  'positive',
#  'atmosphere',
#  'efficient',
#  'directly',
#  'equip',
#  'style',
#  'okay',
#  'clear_instruction',
#  'necessary',
#  'code',
#  'kristina',
#  'anyone_visit',
#  'often',
#  'sink',
#  'dark',
#  'must',
#  'shawn',
#  'roomy',
#  'child',
#  'calm',
#  'finally',
#  'functional',
#  'thoroughly_enjoy',
#  'every_morning',
#  'jon',
#  'hilary',
#  'tiny',
#  'particularly',
#  'drop_off',
#  'nicely_decorate',
#  'instead',
#  'except',
#  'face',
#  'decent',
#  'perfectly_locate',
#  'organize',
#  'cab',
#  'mostly',
#  'richard',
#  'year',
#  'suite',
#  'notice',
#  'blanket',
#  'multiple',
#  'highly',
#  'hot_water',
#  'molly',
#  'feeling',
#  'blue_line',
#  'informative',
#  'few_block',
#  'dish',
#  'imagine',
#  'balcony',
#  'microwave',
#  'transport',
#  'well_decorate',
#  'commute',
#  'little_italy',
#  'eddie',
#  'present',
#  'exactly',
#  'right_across',
#  'art',
#  'steven',
#  'boat',
#  'todd',
#  'erin',
#  'refrigerator',
#  'clearly',
#  'url_hidden',
#  'lack',
#  'third_floor',
#  'alicia',
#  'polite',
#  'require',
#  ...]

# %%
words_embeding = review_sentence2vec.wv.syn0
# Out:
# C:\Users\zzguk\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.wv.vectors instead).
#   """Entry point for launching an IPython kernel.

# %%
words_embeding.shape
# Out:
# (5104, 100)

# %%
#get the words type

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
# Out:
# score:  0.026571788

# %%
ncluster_list = [10,12,14,16,18,20,24,28,32,36,40,45,50,55,60,70,80,90,100]
scores=[]
for nclus in ncluster_list:
    km = KMeans(n_clusters=nclus,random_state=0)
    km.fit(words_embeding)
    predict = km.predict(words_embeding)
    scores.append(silhouette_score(words_embeding,predict))
plt.plot(ncluster_list,scores)

# %%
plt.plot(ncluster_list,scores)

# %%
km = KMeans(n_clusters=20,random_state=0)
km.fit(words_embeding)
cluster_centers = km.cluster_centers_
predict = km.predict(words_embeding)
print("score: ",silhouette_score(words_embeding,predict))
# Out:
# score:  0.01119116

# %%
cluster_centers[0]
# Out:
# array([ 0.01745486, -0.1747259 ,  0.12551558, -0.2529494 , -0.43198276,
#         0.07750716, -0.05697915,  0.0554414 ,  0.08122461,  0.18060288,
#         0.20317586,  0.08757991,  0.02079268,  0.2909552 ,  0.46180514,
#        -0.03748905,  0.07893449,  0.41527712,  0.51905394,  0.16956452,
#        -0.2542652 ,  0.08113921, -0.18844786,  0.00623813,  0.22910783,
#         0.03514064, -0.14481786,  0.03700048,  0.41218796, -0.08932775,
#         0.23054981, -0.19038442,  0.30487543,  0.22532204, -0.0102849 ,
#         0.29535395, -0.11238687, -0.10640235, -0.06645051,  0.09790712,
#        -0.31251487,  0.36262682,  0.19723907,  0.30059677,  0.0703465 ,
#        -0.01400873,  0.02385813,  0.1449029 ,  0.07974094, -0.00862625,
#         0.01690103, -0.21212044, -0.01943779, -0.22818035,  0.16518652,
#        -0.08103151, -0.00666502, -0.1336875 ,  0.15680698,  0.13632222,
#        -0.00772334,  0.20865366, -0.19264683,  0.02252932, -0.04863725,
#        -0.23564224,  0.02601589,  0.46472928, -0.07742356, -0.19776282,
#         0.07995135,  0.5287481 , -0.12377112,  0.26981586, -0.1746355 ,
#        -0.16816942, -0.33255228,  0.24464473, -0.3471645 , -0.2613142 ,
#        -0.43647265,  0.14131036,  0.14060615,  0.2541119 , -0.02706445,
#        -0.06009346, -0.2668717 , -0.5153464 ,  0.0858745 , -0.04090945,
#        -0.11258712,  0.06752668,  0.07982191,  0.27257827,  0.09396644,
#         0.02217202, -0.1604546 ,  0.3244853 ,  0.19419557, -0.00489087],
#       dtype=float32)

# %%
array_index2words = np.array(review_sentence2vec.wv.index2word)

# %%
for i in range(20):
    words = array_index2words[predict==i]
    print("cluster ",i)
    print(words[0:10])
# Out:
# cluster  0
# ['bed' 'bathroom' 'kitchen' 'bedroom' 'sleep' 'big' 'large' 'view'
#  'shower' 'wifi']
# cluster  1
# ['-PRON-' 'be' 'the' 'and' 'to' 'a' 'in' 'very' 'of' 'for']
# cluster  2
# ['door' 'floor' 'stair' 'lock' 'wall' 'dirty' 'smell' 'mattress'
#  'entrance' 'break']
# cluster  3
# ['breakfast' 'coffee' 'morning' 'water' 'snack' 'drink' 'delicious' 'wine'
#  'tea' 'treat']
# cluster  4
# ['helpful' 'check' 'accommodate' 'meet' 'help' 'responsive' 'arrival'
#  'quick' 'communication' 'before']
# cluster  5
# ['close' 'downtown' 'away' 't' 'airport' 'subway' 'near' 'train' 'bus'
#  'short_walk']
# cluster  6
# ['say' 'may' 'expect' 'bit' 'think' 'however' 'problem' 'fine' 'issue'
#  'tell']
# cluster  7
# ['provide' 'give' 'how' 'local' 'instruction' 'information'
#  'recommendation' 'direction' 'tip' 'suggestion']
# cluster  8
# ['host' 'welcome' 'friendly' 'kind' 'who' 'person' 'welcoming' 'dog'
#  'gracious' 'cat']
# cluster  9
# ['jason' 'sean' 'chris' 'jose' 'ari' 'jonathan' 'dan' 'izzy' 'john' 'jay']
# cluster  10
# ['time' 'night' 'day' 'arrive' 'trip' 'family' 'after' '2' 'late' 'spend']
# cluster  11
# ['towel' 'fridge' 'cook' 'extra' 'sheet' 'supply' 'toiletry' 'linen'
#  'stock' 'laundry']
# cluster  12
# ['stay' 'place' 'this' "'s" 'would' 'again' 'thank' 'recommend'
#  'experience' 'will']
# cluster  13
# ['clean' 'comfortable' 'everything' 'perfect' 'spacious' 'cozy' 'small'
#  'picture' 'studio' 'than']
# cluster  14
# ['restaurant' 'nearby' 'shop' 'food' 'eat' 'bar' 'corner' 'store' 'cafe'
#  'dinner']
# cluster  15
# ['host_cancel_this' 'day_before_arrival' 'de' 'et' 'à' 'y' 'un' 'pour'
#  'la' 'en']
# cluster  16
# ['location' 'walk' 'street' 'park' 'explore' 'north_end' 'walk_distance'
#  'common' 'within_walking_distance' 'central']
# cluster  17
# ['lisa' 'sarah' 'robert' 'susan' 'hermina' 'tom' 'joe' 'bruce' 'steve'
#  'alex']
# cluster  18
# ['parking' 'hotel' 'car' 'price' 'value' 'service' 'pay' 'worth' 'money'
#  'less_than']
# cluster  19
# ['home' 'neighborhood' 'wonderful' 'quiet' 'beautiful' 'lovely'
#  'fantastic' 'amazing' 'locate' 'warm']

# %%
array_index2words[predict==2]
# Out:
# array(['responsive', 'respond_quickly', 'respond_promptly',
#        'question_promptly', 'reply_quickly', 'always_respond_quickly',
#        'always_respond_promptly', 'reply_promptly'], dtype='<U28')

# %%
for i in range(20):
    center = cluster_centers[i]
    smallest_i = 0
    smallest_r = 9999
    for j in range(len(words_embeding)):
        dist = center-words_embeding[j]
        r = np.mean(dist*dist)
        if r<smallest_r:
            smallest_r = r
            smallest_i = j
    print("cluster ",i)
    print("center word: "+array_index2words[smallest_i])
# Out:
# cluster  0
# center word: living_room
# cluster  1
# center word: and
# cluster  2
# center word: floor
# cluster  3
# center word: coffee
# cluster  4
# center word: -PRON-
# cluster  5
# center word: t
# cluster  6
# center word: however
# cluster  7
# center word: guide
# cluster  8
# center word: friendly
# cluster  9
# center word: jonathan
# cluster  10
# center word: -PRON-
# cluster  11
# center word: towel
# cluster  12
# center word: -PRON-
# cluster  13
# center word: well_appoint
# cluster  14
# center word: cafe
# cluster  15
# center word: était
# cluster  16
# center word: fenway
# cluster  17
# center word: tom
# cluster  18
# center word: that
# cluster  19
# center word: charming

# %%
review_sentence2vec.wv.most_similar(positive=['bed'],topn=10)
# Out:
# [('mattress', 0.7756842374801636),
#  ('queen_bed', 0.7544865608215332),
#  ('sofa_bed', 0.7341449856758118),
#  ('sofa', 0.7092766761779785),
#  ('couch', 0.7027804255485535),
#  ('king_size_bed', 0.6978681087493896),
#  ('futon', 0.6920413374900818),
#  ('double_bed', 0.6893474459648132),
#  ('queen_size_bed', 0.6831704378128052),
#  ('soft', 0.6745144128799438)]

# %%
array_index2words[predict==0]
# Out:
# array(['bed', 'bathroom', 'kitchen', 'bedroom', 'sleep', 'big', 'large',
#        'view', 'shower', 'wifi', 'living_room', 'window', 'tv', 'light',
#        'hot', 'basement', 'huge', 'cold', 'relax', 'ac', 'fan', 'couch',
#        'upstairs', 'sit', 'internet', 'dining', 'table', 'bath',
#        'weather', 'watch', 'air_conditioning', 'summer', 'deck',
#        'comfy_bed', 'c', 'desk', 'heat', 'private_bathroom', 'bonus',
#        'hot_water', 'balcony', 'third_floor', 'separate', 'soft', 'air',
#        'chair', 'air_conditioner', 'patio', 'sofa', 'air_mattress',
#        'temperature', 'roof_deck', 'super_comfy', 'wi_fi', 'top_floor',
#        'first_floor', 'cable', 'natural_light', 'feature', 'heater',
#        'second_floor', 'netflix', 'porch', 'backyard', 'rooftop',
#        'sofa_bed', '3rd_floor', 'water_pressure', 'sized', 'futon',
#        'lounge', 'heating', 'sun', 'rooftop_deck', 'movie', 'double',
#        'private_entrance', 'storage', 'air_condition', 'gym', 'roof',
#        'cable_tv', 'private_bath', 'pool', 'living_area', 'terrace',
#        'master_bedroom', 'overlook', 'restroom', 'queen_bed',
#        'fully_equip_kitchen', 'lighting', 'window_open', 'ac_unit',
#        'computer', '2nd_floor', 'dresser', 'ceiling_fan', 'sleeping',
#        'sunset', 'upgrade', 'attic', 'function', 'channel', 'television',
#        'high_ceiling', 'surprisingly', 'window_unit', 'double_bed',
#        'thermostat', 'back_porch', 'fireplace', 'pull_out',
#        'space_heater', 'courtyard', 'no_ac', 'master', 'fire', 'sunlight',
#        'study', 'c_unit', 'pull_out_couch', 'watch_tv', 'apple_tv',
#        'laptop', 'outdoor', 'spread_out', 'back_yard', 'exercise',
#        'internet_connection', 'communal', 'screen', 'air_con', 'temp',
#        'laundry_facility', 'degree', 'indoor', 'bbq', 'queen_size_bed',
#        'seat', 'piano', 'shade', 'seating', 'wireless', 'fast_wifi',
#        'twin', 'separate_entrance', 'hardwood_floor', 'queen',
#        'free_wifi', 'low_level', 'attach', 'king_size_bed', 'giant',
#        'din', 'sunshine', 'living_space', 'dining_table',
#        'wireless_internet', 'twin_bed', 'video', 'fluffy', 'full_size',
#        'back_patio', 'rooftop_patio', 'fall_asleep', 'wide', 'projector',
#        'air_conditioning_unit', 'front_porch', 'aircon', 'heat_wave',
#        'massive', 'outdoor_space', 'workout', 'gather', 'dvd', 'roof_top',
#        'signal', 'fresh_air', 'weak', 'memory_foam', 'own_entrance',
#        'huge_bonus', 'central_air', 'cot', 'heated', 'roof_top_deck',
#        'rear', 'nest', 'unwind', 'powerful', 'full_bath', 'fast_internet',
#        'skylight', 'sit_outside', 'reading', 'hook', 'device', 'medium',
#        'roku', 'roof_terrace', 'add_bonus', 'sleep_comfortably',
#        'main_floor', 'working', 'roofdeck', 'convert', 'king_bed',
#        'murphy_bed', 'huge_tv', 'separate_bedroom', 'fold_out',
#        'bunk_bed', 'c.', 'hangout', 'bit_tight', 'flow', 'nook',
#        'window_ac_unit', 'wifi_connection', 'flat_screen_tv',
#        'bay_window', 'sunrise', 'hot_tub', 'enormous', 'upper_floor',
#        'ensuite', 'memory_foam_mattress', 'hang_clothe', 'freely',
#        '90_degree', 'full_size_bed', 'half_bath', 'ridiculously', 'king',
#        'heavenly', 'real_bonus', 'walkway', 'consist', 'ground_level',
#        'lifesaver', 'watch_netflix', 'crisp', 'pull_out_sofa',
#        'watch_movie', 'wifi_signal', 'sound_system', 'massage_chair',
#        'web', 'real_plus', 'log', 'outdoor_patio',
#        'window_air_conditioner', 'cold_outside', 'plush', 'amazon',
#        'rooftop_terrace', 'hammock', 'our', 'livingroom', 'stream',
#        'basement_level', 'streaming', 'shared', 'pullout_couch', 'hbo',
#        'hot_weather', 'shower_pressure', 'big_screen_tv', 'queen_size',
#        'spectacular_view', 'button', 'jacuzzi', 'hook_up', 'fitness',
#        'writing', 'sitting_room', 'combo', 'br', 'fox'], dtype='<U28')

# %%
review_sentence2vec.wv.similarity('bed','wifi')
# Out:
# 0.44519122271974665

# %%
#make a tag for each word
